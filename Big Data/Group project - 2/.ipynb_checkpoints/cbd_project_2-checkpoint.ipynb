# %%
import pandas as pd
import pandas_profiling as profile
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import plotly.express as px
import seaborn as sns
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

# %%
cancer_dataset = pd.read_csv('data/cancer.csv')
cancer_dataset_bkp = cancer_dataset.copy()

# %%
cancer_dataset.head()
# Out:
#         id  Clump Thickness  UofCSize  UofCShape  Marginal Adhesion  SECSize  \
# 0  1000025                5         1          1                  1        2
# 1  1002945                5         4          4                  5        7
# 2  1015425                3         1          1                  1        2
# 3  1016277                6         8          8                  1        3
# 4  1017023                4         1          1                  3        2
#
#    Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0            1                3                1        1      2
# 1           10                3                2        1      2
# 2            2                3                1        1      2
# 3            4                3                7        1      2
# 4            1                3                1        1      2

# %%
cancer_dataset.shape
# Out:
# (683, 11)

# %%
cancer_dataset = cancer_dataset.drop(['id'],axis = 1)

# %%
cancer_dataset.head()
# Out:
#    Clump Thickness  UofCSize  UofCShape  Marginal Adhesion  SECSize  \
# 0                5         1          1                  1        2
# 1                5         4          4                  5        7
# 2                3         1          1                  1        2
# 3                6         8          8                  1        3
# 4                4         1          1                  3        2
#
#    Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0            1                3                1        1      2
# 1           10                3                2        1      2
# 2            2                3                1        1      2
# 3            4                3                7        1      2
# 4            1                3                1        1      2

# %%
print(cancer_dataset.iloc[:,-1].value_counts())
# Out:
# 2    444
# 4    239
# Name: Class, dtype: int64

# %%
#profile.ProfileReport(cancer_dataset)

# %%
cancer_dataset.columns
# Out:
# Index(['Clump Thickness', 'UofCSize', 'UofCShape', 'Marginal Adhesion',
#        'SECSize', 'Bare Nuclei', 'Bland Chromatin', 'Normal Nucleoli',
#        'Mitoses', 'Class'],
#       dtype='object')

# %%
cancer_dataset_preprocess = cancer_dataset.iloc[:, :-1].values

one_hot_encoder = OneHotEncoder(sparse=False)
one_hot_encoder.fit(cancer_dataset_preprocess)

cancer_dataset_preprocess = one_hot_encoder.transform(cancer_dataset_preprocess)

# %%
cancer_dataset_preprocess.shape
# Out:
# (683, 89)

# %%
actual_value = list(cancer_dataset['Class'])

# %%
Error =[]
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i).fit(cancer_dataset_preprocess)
    kmeans.fit(cancer_dataset_preprocess)
    Error.append(kmeans.inertia_)
import matplotlib.pyplot as plt
plt.plot(range(1, 11), Error)
plt.title('Elbow method')
plt.xlabel('No of clusters')
plt.ylabel('Error')
plt.show()

# %%
kmeans = KMeans(n_clusters = 2)
y_kmeans = kmeans.fit_predict(cancer_dataset_preprocess)

# %%
cancer_dataset['Cluster'] = y_kmeans

# %%
cancer_dataset.groupby(['Class','Cluster']).size()
# Out:
# Class  Cluster
# 2      0           32
#        1          412
# 4      0          237
#        1            2
# dtype: int64

# %%
#Creating a 2D visualization to visualize the clusters
from sklearn.manifold import TSNE
tsne = TSNE(verbose=1, perplexity=40, n_iter= 4000)
Y = tsne.fit_transform(cancer_dataset_preprocess)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 683 samples in 0.021s...
# [t-SNE] Computed neighbors for 683 samples in 0.060s...
# [t-SNE] Computed conditional probabilities for sample 683 / 683
# [t-SNE] Mean sigma: 0.877173
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 63.591518
# [t-SNE] KL divergence after 2000 iterations: 0.856016

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)

ax1.scatter(Y[:,0],Y[:,1],  c=y_kmeans, cmap = "jet", edgecolor = "None", alpha=0.35)
ax1.set_title('k-means clustering plot')

ax2.scatter(Y[:,0],Y[:,1],  c =actual_value , cmap = "jet", edgecolor = "None", alpha=0.35)
ax2.set_title('Actual clusters')
# Out:
# Text(0.5, 1.0, 'Actual clusters')
